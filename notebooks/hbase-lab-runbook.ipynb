# %% [markdown]
# # HBase Lab Runbook
#
# Portfolio companion to the original lab artifact. Original documents remain preserved.
#
# ## Journey
# Setup, table model, write operations, read operations, scans, validation, and modernization.
#
# ## Compatibility Lens
# Keep historical exercises intact and add current notes separately. Modern HBase work should be checked against the supported HBase and Hadoop compatibility matrix, current Java runtime support, client APIs, and deployment platform. For some access patterns, managed wide-column services may be a modern operational alternative.
#
# ## Evidence
# Place reviewed screenshots beside the step they demonstrate.
#
# ## Validation
# Check row-key assumptions, column-family design, write/read results, scan behavior, and access-pattern fit.
#
# ## Future State
# Add the source sequence, screenshots, sample records, expected results, and a historical-to-current platform comparison.
